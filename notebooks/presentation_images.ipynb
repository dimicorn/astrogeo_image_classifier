# %%
import os
import matplotlib.pyplot as plt
from yaml import safe_load
from munch import munchify
from pre.load import fits2numpy
from pre.preprocess import preprocess_lognorm


with open(os.getenv("CONFIG_PATH")) as f:
    cfg = munchify(safe_load(f))

# %%
root_dir = "/data/zagorulia/synt_points_no_bk"
data_raw = fits2numpy(f"{root_dir}/gamma_2.0_theta_0.1_b_0.6_k_6.1_alpha_-0.9.fits")
data_lognorm = preprocess_lognorm(data_raw)
plt.imshow(data_lognorm)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(127.5), np.float64(127.5), np.float64(-0.5))

# %%
data_raw = fits2numpy(f"{cfg.ilya_single_jets_fits}/cc_1.fits")
data_lognorm = preprocess_lognorm(data_raw)
plt.imshow(data_lognorm)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(127.5), np.float64(127.5), np.float64(-0.5))

# %%
data_raw = fits2numpy(f"{cfg.fits_path}/J2359+2036/J2359+2036_C_2014_02_03_pet_map.fits")
data_lognorm = preprocess_lognorm(data_raw)
plt.title('J2359+2036, 2014-02-03')
plt.imshow(data_lognorm, origin="lower")
plt.tight_layout()
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(127.5), np.float64(-0.5), np.float64(127.5))

# %%
data_raw = fits2numpy(f"{cfg.fits_path}/J1229+0203/J1229+0203_Q_2019_01_10_mar_map.fits")
data_raw = data_raw[
        2 * data_raw.shape[0]//5: ,
        : 3 * data_raw.shape[1]//5
    ]

data_lognorm = preprocess_lognorm(data_raw)
plt.title('J1229+0203, 2019-01-10')
plt.imshow(data_lognorm, origin="lower")
plt.tight_layout()
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(127.5), np.float64(-0.5), np.float64(127.5))

# %%
data_raw = fits2numpy(f"{cfg.fits_path}/J0057+3021/J0057+3021_X_2018_12_18_pet_map.fits") 
data_lognorm = preprocess_lognorm(data_raw)
plt.title('J0057+3021, 2018-12-18')
plt.imshow(data_lognorm, origin="lower")
plt.tight_layout()
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(127.5), np.float64(-0.5), np.float64(127.5))
