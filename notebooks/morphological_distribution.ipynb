# %%
import pandas as pd
import matplotlib.pyplot as plt

classification = pd.read_csv("/home/zagorulia/ml/classification_new.csv", index_col=0)
classification.head()
# Out:
#                                    file      prob  pred  intensity
# 0  J0000+0248_C_2016_01_03_pet_map.fits  0.000089     0   6.309561
# 1  J0000+0248_S_2022_01_07_pet_map.fits  0.000024     0   7.179761
# 2  J0000+0248_X_2016_01_03_pet_map.fits  0.081690     0   2.300029
# 3  J0000+0248_X_2022_01_07_pet_map.fits  0.001513     0   2.269862
# 4  J0000+0307_C_2015_12_23_pet_map.fits  0.027874     0   6.744466

# %%
classification.shape
# Out:
# (134046, 4)

# %%
classification[(classification.prob > 0.25) & (classification.prob < 0.75)].shape
# Out:
# (15159, 4)

# %%
15159 / 134046 * 100
# Out:
# 11.308804440266774

# %%
classification.prob.hist(bins=50)
plt.yscale('log')
