# %%
from pre.load import fits2numpy
from pre.preprocess import preprocess_lognorm
import os
import matplotlib.pyplot as plt

# %%
root_dir = "/data/zagorulia/synt_points_no_bk"
files = os.listdir(root_dir)[:10]
files
# Out:
# ['gamma_1.6_theta_0.1_b_0.5_k_5.4_alpha_-1.0.fits',
#  'gamma_1.9_theta_0.1_b_0.4_k_5.2_alpha_-1.0.fits',
#  'gamma_1.3_theta_0.1_b_0.6_k_6.4_alpha_-1.1.fits',
#  'gamma_1.7_theta_0.1_b_0.3_k_4.8_alpha_-0.8.fits',
#  'gamma_1.2_theta_0.1_b_0.6_k_4.7_alpha_-1.1.fits',
#  'gamma_2.0_theta_0.1_b_0.6_k_6.1_alpha_-0.9.fits',
#  'gamma_1.5_theta_0.1_b_0.5_k_4.6_alpha_-1.1.fits',
#  'gamma_1.4_theta_0.1_b_0.6_k_5.8_alpha_-1.1.fits',
#  'gamma_1.3_theta_0.1_b_0.6_k_5.5_alpha_-1.1.fits',
#  'gamma_1.9_theta_0.1_b_0.2_k_5.2_alpha_-1.1.fits']

# %%
data_raw = fits2numpy(f"{root_dir}/{files[3]}") # gamma_1.7_theta_0.1_b_0.3_k_4.8_alpha_-0.8.fits
data_lognorm = preprocess_lognorm(data_raw)[40:87, 40:87]
plt.imshow(data_lognorm)

# %%
img_path = "/home/zagorulia/bk_simulation/test/gamma_1.7_theta_0.1_b_0.3_k_4.8_alpha_-0.8.fits"

data_raw = fits2numpy(img_path)
data_lognorm = preprocess_lognorm(data_raw)[40:87, 40:87]
plt.imshow(data_lognorm)
